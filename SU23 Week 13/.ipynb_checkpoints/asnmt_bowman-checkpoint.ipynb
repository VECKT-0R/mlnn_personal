# %% [markdown]
# # NLP
# Find your favorite news source and grab the article text.
#
# 1. Show the most common words in the article.
# 2. Show the most common words under a part of speech. (i.e. NOUN: {'Bob':12, 'Alice':4,})
# 3. Find a subject/object relationship through the dependency parser in any sentence.
# 4. Show the most common Entities and their types.
# 5. Find Entites and their dependency (hint: entity.root.head)
# 6. Find the most similar words in the article

# %% [markdown]
# Note: Yes, the notebook from the video is not provided, I leave it to you to make your own :) it's your final assignment for the semester. Enjoy!

# %%
# Installing Spacy

# !pip3 install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.6.0-cp310-cp310-macosx_10_9_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 21.3 MB/s eta 0:00:0000:0100:01
# Collecting typer<0.10.0,>=0.3.0
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 1.5 MB/s eta 0:00:00
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Requirement already satisfied: setuptools in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy) (65.6.3)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: numpy>=1.15.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy) (1.23.5)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.7-cp310-cp310-macosx_10_9_x86_64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.7/492.7 kB 12.7 MB/s eta 0:00:00
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.2-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 1.6 MB/s eta 0:00:00
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.12-cp310-cp310-macosx_10_9_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 23.8 MB/s eta 0:00:0000:0100:01
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp310-cp310-macosx_10_9_x86_64.whl (18 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp310-cp310-macosx_10_9_x86_64.whl (32 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp310-cp310-macosx_10_9_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 4.0 MB/s eta 0:00:00
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.11-cp310-cp310-macosx_10_9_x86_64.whl (859 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 859.7/859.7 kB 15.4 MB/s eta 0:00:0000:01
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy) (22.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy) (4.64.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: jinja2 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy) (2.28.1)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.9-py3-none-any.whl (17 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.10-cp310-cp310-macosx_10_9_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 26.4 MB/s eta 0:00:0000:0100:01
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from jinja2->spacy) (2.1.1)
# Installing collected packages: cymem, wasabi, typer, spacy-loggers, spacy-legacy, pydantic, murmurhash, langcodes, catalogue, blis, srsly, preshed, pathy, confection, thinc, spacy
# Successfully installed blis-0.7.10 catalogue-2.0.9 confection-0.1.1 cymem-2.0.7 langcodes-3.3.0 murmurhash-1.0.9 pathy-0.10.2 preshed-3.0.8 pydantic-1.10.12 spacy-3.6.0 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.7 thinc-8.1.11 typer-0.9.0 wasabi-1.1.2

# %%
# Downloading Model

# !python3 -m spacy download en
# Out:
# 2023-08-07 19:16:34.481344: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 24.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from en-core-web-sm==3.6.0) (3.6.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (5.2.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (22.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: jinja2 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.9)
# Requirement already satisfied: pathy>=0.10.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.28.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: numpy>=1.15.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.23.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.11)
# Requirement already satisfied: setuptools in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (65.6.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.10.12)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Importing Spacy

import spacy as sy
# Out:
# 2023-08-07 19:17:05.887324: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Build Model

nlp = sy.load('en_core_web_sm')

# %%
# Load Article

# wapo = open('../data/wapo_article.txt', "rb").read() doesn't work

# %%
# Load Article

# I tried loading both .docx and .txt files and both generated a "ExtraData: unpack(b) received extra data." Error so I gave up and copy pasted. I find this deeply inefficient.

wapo = """FACING THE SURGE
SCROLL DOWN TO CONTINUE

With a fast burst of sea level rise, New Orleans’s outer defenses face a major test

ByChris Mooney, 
Zoeann Murphy, 
Ricky Carioti and 
John Muyskens
Aug. 7 at 6:00 a.m.


Louisiana armed itself against the seas in the years after Hurricane Katrina, working to rebuild a shrinking coastline while factoring in the potential for dire climate change.
But since 2010, the U.S. Gulf Coast has seen a sudden burst of rapid sea level rise, with rates that scientists didn’t expect to see until late this century. At its center lie the wetlands that make up the first line of defense for New Orleans, buffering the levees and barriers behind them. The change has put the city and its nearby coastal communities at greater risk from storms.
At Shell Beach, just two miles from commercial fisherman Charles Robin’s small boat dock, the sea has risen about seven inches since 2009, according to data from the National Oceanic and Atmospheric Administration.

Scientists with the U.S. Geological Survey and the state have been closely monitoring Louisiana’s wetlands. They’ve set up nearly 400 sampling stations, each a square kilometer in size, to track the change. For many of the brackish and saltwater marshes near the Gulf of Mexico, there’s been a clear uptick in land losses since around 2015.
Chart shows estuarine marshes in the Terrebonne, Barataria, Breton Sound, and Pontchartrain basins. Source: Couvillion, B.R. (2023)*

Chart shows saltwater and brackish marshes in the Terrebonne, Barataria, Breton Sound and Pontchartrain basins.
Source: Brady Couvillion
“This is becoming a trend that we’ve seen for six or seven years now,” said Brady Couvillion, a coastal geographer with the U.S. Geological Survey who charts the wetland changes. “It’s definitely piqued our interest.”
Glover’s father died in 2007. She knew her dad, engineer John Edgar Land, had been a longtime state employee. But it wasn’t until last year that she learned he’d apparently been involved in designing the state’s first large engineered river-diversion project, constructed long before the current race to defend the coast.
In an old box she found in her brother’s house, Glover discovered plans for the Bayou Lamoque Freshwater Diversion. Built in the mid-1950s to help oyster fishermen by driving back salt water, it contained gates that lifted to channel up to 4,000 cubic feet of fresh water per second into the marshes behind it.
Locator map that shows the location of the following map within Louisiana

New
Orleans
Detail
Map showing the location of a freshwater diversion built in the 1950s between the Mississippi River and Breton Sound
BRETON
SOUND
Freshwater diversion
built in the 1950s
1 MILE
Source: Satellite imagery via Planet Labs PBC
Today, the diversion is in disrepair, apparently clogged with so much Mississippi River silt you can walk around it. When the diversion was working, that silt would have flowed through with the water, likely forming land amid the vibrant marshes farther inland.
Land’s name is not on the plans, but Glover says she recognizes the handwriting.

Louisiana is planning two far more massive diversions, one channeling the Mississippi west into the struggling marshes of Barataria and another pouring fresh water east into the equally imperiled wetlands of Breton Sound. Work on the first project, in mid-Barataria, is set to begin Tuesday.
The mid-Barataria diversion will cost $ 2.9 billion and channel enormous volumes of water, up to 75,000 cubic feet per second. Together, the two diversions are one of the core components of the state’s Coastal Master Plan

The question now is, with seas rising faster than expected and wetlands steadily losing ground, will it be enough?
A linked fate
Today, New Orleans’s coastal barrier system is designed to protect against the surge from a major hurricane and recently withstood Hurricane Ida, a powerful Category 4 storm, without being overtopped.
But rising seas mean levees and barriers might have to be reworked. As wetlands shrink, hurricanes face fewer speed bumps as they assault the coast. And no matter how high the barriers are, New Orleans will be less safe if the wetlands and the fishing communities the city depends on disappear.

Austin Feldbaum heads up hazard mitigation at New Orleans’s Office of Homeland Security and Emergency Preparedness. The fate of the city, and the wetlands communities surrounding it, are inextricably connected, he said.
The city has built a comprehensive strategy against storms that includes levees, pumps and building codes.
“The preservation and restoration of coastal wetlands is a critical piece of that,” he said.
And as seas continue to rise, the impacts will not be borne equally, said Michael Esealuka, an environmental justice organizer in Louisiana.

About this story
Design and development by Hailey Haymond. Editing by Katie Zezima, Angela M. Hill, Amanda Voisard, Joe Moore and Monica Ulmanu. Copy editing by Emily Morman.
Data on Louisiana wetland changes is from Brady Couvillion’s work on behalf of the 2023 Draft Coastal Master Plan, Attachment D6. Louisiana State University doctoral candidate Daena Carrillo shared John Edgar Land’s plans and papers. Don Davis, Louisiana Sea Grant scholar, provided historical research on the Bayou Lamoque Freshwater Diversion.
The map comparing wetlands in 1985 and 2020 uses cloud-free mosaics of Landsat 5 imagery from June 1984 to June 1986, and Landsat 8 imagery from 2020. The satellite imagery is masked over water using Landsat-derived water data from Couvillion."""

# %%
# Process Article

wapo_proc = nlp(wapo)

# %%
# Word Counting

from collections import Counter

words = [token.text
         for token in wapo_proc
         if not token.is_stop and not token.is_punct and not token.is_space]


word_freq = Counter(words)
common_words = word_freq.most_common(10)
print(common_words)
# Out:
# [('wetlands', 20), ('Louisiana', 17), ('sea', 9), ('rise', 9), ('state', 9), ('Barataria', 9), ('water', 9), ('New', 8), ('Orleans', 8), ('marshes', 8)]

# %% [markdown]
#     The top 10 most common words in the article are 'wetlands' with 20, 'Louisiana' with 17, 'sea' with 9, 'rise' with 9, 'state' with 9, 'New' with 8, 'Orleans' with 8, and 'marshes' with 8. I excluded what Spacy calls 'stop words' ie 'the', 'a' etc.

# %%
# Type Counting

nouns = [token.text
         for token in wapo_proc
         if (not token.is_stop and
             not token.is_punct and
             token.pos_ == "NOUN")]

noun_freq = Counter(nouns)
common_nouns = noun_freq.most_common(5)

verbs = [token.text
         for token in wapo_proc
         if (not token.is_stop and
             not token.is_punct and
             token.pos_ == "VERB")]

verb_freq = Counter(verbs)
common_verbs = verb_freq.most_common(5)

adjectives = [token.text
              for token in wapo_proc
              if (not token.is_stop and
                  not token.is_punct and
                  token.pos_ == "ADJ")]

adj_freq = Counter(adjectives)
common_adj = adj_freq.most_common(5)

adverbs = [token.text
           for token in wapo_proc
           if (not token.is_stop and
               not token.is_punct and
               token.pos_ == "ADV")]

adv_freq = Counter(adverbs)
common_adv = adv_freq.most_common(5)

propers = [token.text
           for token in wapo_proc
           if (not token.is_stop and
               not token.is_punct and
               token.pos_ == "PROPN")]

propn_freq = Counter(propers)
common_propn = propn_freq.most_common(5)

print(common_nouns, common_verbs, common_adj, common_adv, common_propn)
# Out:
# [('wetlands', 19), ('sea', 9), ('state', 9), ('water', 9), ('level', 7)] [('said', 7), ('seen', 4), ('shows', 4), ('built', 4), ('rebuild', 3)] [('coastal', 7), ('major', 4), ('middle', 3), ('current', 3), ('environmental', 3)] [('faster', 4), ('farther', 2), ('potentially', 2), ('apparently', 2), ('equally', 2)] [('Louisiana', 17), ('New', 8), ('Orleans', 8), ('Barataria', 8), ('Breton', 7)]

# %% [markdown]
#     The top 5 most common nouns are 'wetlands' with 19 instances, 'sea' with 9, 'water' with 9, and 'level' with 7.
#
#     The top 5 most common verbs are 'said' with 7 instances, 'seen' with 4, 'shows' with 4, 'built' with 4, and 'rebuild' with 3.
#
#     The top 5 most common adjectives are 'coastal' with 7 instances, 'major' with 4, 'middle' with 3, 'current' with 3, and 'environmental' with 3.
#
#     The top 5 most common adverbs are 'faster' with 4 instances, 'farther' with 2, 'potentially' with 2, 'apparently' with 2, and 'equally' with 2.
#
#     The top 5 most common proper nouns are 'Louisiana' with 17 instances, 'New' and 'Orleans' with 8, 'Barataria' with 8, and 'Breton' with 7.

# %%
# Dependencies Parser

def pr_tree(word, level):
    if word.is_punct:
        return
    for child in word.lefts: 
        pr_tree (child, level+1) 
    print('\t'* level + word.text + ' - ' + word.dep_)
    for child in word.rights:
        pr_tree (child, level+1)

# %%
# Parsing

sentence_spans = list(wapo_proc.sents)

for sentence in sentence_spans[3]:
    pr_tree(sentence, 0)
# Out:
# At - prep
# 		its - poss
# 	center - pobj
# its - poss
# 	its - poss
# center - pobj
# 	At - prep
# 			its - poss
# 		center - pobj
# lie - ROOT
# 		the - det
# 	wetlands - dobj
# 			that - nsubj
# 		make - relcl
# 			up - prt
# 				the - det
# 				first - amod
# 			line - dobj
# 				of - prep
# 					defense - pobj
# 				for - prep
# 						New - compound
# 					Orleans - pobj
# 			buffering - advcl
# 					the - det
# 				levees - dobj
# 					and - cc
# 					barriers - conj
# 					behind - prep
# 						them - pobj
# the - det
# 	the - det
# wetlands - dobj
# 		that - nsubj
# 	make - relcl
# 		up - prt
# 			the - det
# 			first - amod
# 		line - dobj
# 			of - prep
# 				defense - pobj
# 			for - prep
# 					New - compound
# 				Orleans - pobj
# 		buffering - advcl
# 				the - det
# 			levees - dobj
# 				and - cc
# 				barriers - conj
# 				behind - prep
# 					them - pobj
# that - nsubj
# 	that - nsubj
# make - relcl
# 	up - prt
# 		the - det
# 		first - amod
# 	line - dobj
# 		of - prep
# 			defense - pobj
# 		for - prep
# 				New - compound
# 			Orleans - pobj
# 	buffering - advcl
# 			the - det
# 		levees - dobj
# 			and - cc
# 			barriers - conj
# 			behind - prep
# 				them - pobj
# up - prt
# the - det
# first - amod
# 	the - det
# 	first - amod
# line - dobj
# 	of - prep
# 		defense - pobj
# 	for - prep
# 			New - compound
# 		Orleans - pobj
# of - prep
# 	defense - pobj
# defense - pobj
# for - prep
# 		New - compound
# 	Orleans - pobj
# New - compound
# 	New - compound
# Orleans - pobj
# buffering - advcl
# 		the - det
# 	levees - dobj
# 		and - cc
# 		barriers - conj
# 		behind - prep
# 			them - pobj
# the - det
# 	the - det
# levees - dobj
# 	and - cc
# 	barriers - conj
# 	behind - prep
# 		them - pobj
# and - cc
# barriers - conj
# behind - prep
# 	them - pobj
# them - pobj

# %%
# Displacy Dendencies

from spacy import displacy

sentence_spans = list(wapo_proc.sents)
displacy.render(sentence_spans[3], style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="34b158a459424193929a951931126dc6-0" class="displacy" width="4250" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">At</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">center</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">lie</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">wetlands</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">make</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">up</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">line</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">defense</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">New</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Orleans,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">buffering</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">levees</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">barriers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">behind</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">them.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PRON</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-34b158a459424193929a951931126dc6-0-0" stroke-width="2px" d="M70,352.0 C70,89.5 570.0,89.5 570.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-34b158a459424193929a951931126dc6-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-34b158a459424193929a951931126dc6-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-34b158a459424193929a951931126dc6-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-34b158a459424193929a951931126dc6-0-2" stroke-width="2px" d="M70,352.0 C70,177.0 390.0,177.0 390.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-34b158a459424193929a951931126dc6-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M390.0,354.0 L398.0,342.0 382.0,342.0" fill="cur

# %% [markdown]
#     Below is one of the sentences from the Displacy render. You can see the relations within the sentence next to the word. Reference the render for the full arrows.
#
# At ADP
# its PRON
# center NOUN
# lie VERB
# the DET
# wetlands NOUN
# that PRON
# make VERB
# up ADP
# the DET
# first ADJ
# line NOUN
# of ADP
# defense NOUN
# for ADP
# New PROPN
# Orleans, PROPN
# buffering VERB
# the DET
# levees NOUN
# and CCONJ
# barriers NOUN
# behind ADP
# them. PRON

# %%
# Finding Entities & Labels

entities = [(entity.text, entity.label_)
            for entity in wapo_proc.ents]

entities_freq = Counter(entities)
common_entities = entities_freq.most_common(10)

print(common_entities)
# Out:
# [(('Louisiana', 'GPE'), 14), (('Barataria', 'GPE'), 6), (('New Orleans', 'GPE'), 4), (('Breton Sound', 'GPE'), 4), (('the Mississippi River', 'LOC'), 4), (('first', 'ORDINAL'), 3), (('1985', 'DATE'), 3), (('2020', 'DATE'), 3), (('Glover', 'PERSON'), 3), (('New Orleans’s', 'GPE'), 2)]

# %% [markdown]
#     The top 10 most common entities in this article are 'Louisiana' with 14 instances, 'Barataria' with 6, 'Breton Sound' with 5, 'New Orleans' with 4, 'the Mississippi River' with 4, 'Glover' with 4, 'first' with 3, '1985' with 3, '2020' with 3, and 'New Orleans's' with 2. The model has distinguished between 'New Orleans' and 'New Orleans's' which is fascinating. I am also uncertain why 'Louisiana' has 17 instances when looking at proper nouns but only 14 when looking at entities.
#     The entity types are as follows: Louisiana is a geopolitical entity (GPE), Barataria is a GPE, Breton Sound is a GPE, New Orleans is a GPE, the Mississippi River is a location (LOC), Glover is a person, first is ordinal, 1985 is a date, 2020 is a date, and New Orleans's is a GPE.

# %%
# Entity Dependencies

for entity in wapo_proc.ents:
    pr_tree(entity.root.head, 0)
# Out:
# FACING - advcl
# 		THE - det
# 	SURGE - dobj
#
#  - dep
# 		SCROLL - appos
# 	DOWN - prt
# 		TO - prep
# 			CONTINUE - pobj
#
#
#  - dep
# 	With - prep
# 			a - det
# 			fast - amod
# 		burst - pobj
# 			of - prep
# 						sea - compound
# 					level - compound
# 				rise - pobj
# 		New - compound
# 	Orleans - poss
# 		’s - case
# 	outer - amod
# defenses - nsubj
# 	FACING - advcl
# 			THE - det
# 		SURGE - dobj
#
#  - dep
# 			SCROLL - appos
# 		DOWN - prt
# 			TO - prep
# 				CONTINUE - pobj
#
#
#  - dep
# 		With - prep
# 				a - det
# 				fast - amod
# 			burst - pobj
# 				of - prep
# 							sea - compound
# 						level - compound
# 					rise - pobj
# 			New - compound
# 		Orleans - poss
# 			’s - case
# 		outer - amod
# 	defenses - nsubj
# face - ROOT
# 		a - det
# 		major - amod
# 		test - compound
#
#
#  - dep
# 		ByChris - compound
# 	Mooney - dobj
# 			Zoeann - compound
# 		Murphy - appos
# 				Ricky - compound
# 			Carioti - conj
# 				  - dep
# 				and - cc
#
#  - dep
# 					John - compound
# 				Muyskens - conj
#
#  - dep
# 					Aug. - appos
# 						7 - nummod
# 	at - prep
# 		6:00 - pobj
# 	a.m. - punct
#
#
#
#  - dep
# 	a - det
# 	major - amod
# 	test - compound
#
#
#  - dep
# 	ByChris - compound
# Mooney - dobj
# 		Zoeann - compound
# 	Murphy - appos
# 			Ricky - compound
# 		Carioti - conj
# 			  - dep
# 			and - cc
#
#  - dep
# 				John - compound
# 			Muyskens - conj
#
#  - dep
# 				Aug. - appos
# 					7 - nummod
# 	Zoeann - compound
# Murphy - appos
# 		Ricky - compound
# 	Carioti - conj
# 		  - dep
# 		and - cc
#
#  - dep
# 			John - compound
# 		Muyskens - conj
#
#  - dep
# 			Aug. - appos
# 				7 - nummod
# 	Ricky - compound
# Carioti - conj
# 	  - dep
# 	and - cc
#
#  - dep
# 		John - compound
# 	Muyskens - conj
#
#  - dep
# 		Aug. - appos
# 			7 - nummod
# 	John - compound
# Muyskens - conj
#
#  - dep
# 	Aug. - appos
# 		7 - nummod
# 	FACING - advcl
# 			THE - det
# 		SURGE - dobj
#
#  - dep
# 			SCROLL - appos
# 		DOWN - prt
# 			TO - prep
# 				CONTINUE - pobj
#
#
#  - dep
# 		With - prep
# 				a - det
# 				fast - amod
# 			burst - pobj
# 				of - prep
# 							sea - compound
# 						level - compound
# 					rise - pobj
# 			New - compound
# 		Orleans - poss
# 			’s - case
# 		outer - amod
# 	defenses - nsubj
# face - ROOT
# 		a - det
# 		major - amod
# 		test - compound
#
#
#  - dep
# 		ByChris - compound
# 	Mooney - dobj
# 			Zoeann - compound
# 		Murphy - appos
# 				Ricky - compound
# 			Carioti - conj
# 				  - dep
# 				and - cc
#
#  - dep
# 					John - compound
# 				Muyskens - conj
#
#  - dep
# 					Aug. - appos
# 						7 - nummod
# 	at - prep
# 		6:00 - pobj
# 	a.m. - punct
#
#
#
#  - dep
# 	Louisiana - nsubj
# armed - ROOT
# 	itself - dobj
# 	against - prep
# 			the - det
# 		seas - pobj
# 			in - prep
# 					the - det
# 				years - pobj
# 	after - prep
# 			Hurricane - compound
# 		Katrina - pobj
# 	working - advcl
# 			to - aux
# 		rebuild - advcl
# 				a - det
# 				shrinking - amod
# 			coastline - dobj
# 				while - mark
# 			factoring - advcl
# 				in - prep
# 						the - det
# 					potential - pobj
# 						for - prep
# 								dire - amod
# 								climate - compound
# 							change - pobj
# in - prep
# 		the - det
# 	years - pobj
# after - prep
# 		Hurricane - compound
# 	Katrina - pobj
# since - prep
# 	2010 - pobj
# 	But - cc
# 	since - prep
# 		2010 - pobj
# 		the - det
# 		U.S. - compound
# 		Gulf - compound
# 	Coast - nsubj
# 	has - aux
# seen - ROOT
# 		a - det
# 		sudden - amod
# 	burst - dobj
# 		of - prep
# 					rapid - amod
# 					sea - compound
# 				level - compound
# 			rise - pobj
# 				with - prep
# 					rates - pobj
# 							scientists - nsubj
# 							did - aux
# 							n’t - neg
# 						expect - relcl
# 								that - dobj
# 								to - aux
# 							see - xcomp
# 								until - prep
# 										late - amod
# 										this - det
# 									century - pobj
# until - prep
# 		late - amod
# 		this - det
# 	century - pobj
# 	the - det
# 	first - amod
# line - dobj
# 	of - prep
# 		defense - pobj
# 	for - prep
# 			New - compound
# 		Orleans - pobj
# for - prep
# 		New - compound
# 	Orleans - pobj
# At - prep
# 		Shell - compound
# 	Beach - pobj
# 			just - advmod
# 		two - nummod
# 	miles - npadvmod
# from - prep
# 				commercial - amod
# 			fisherman - compound
# 			Charles - compound
# 		Robin - poss
# 			’s - case
# 			small - amod
# 		boat - compound
# 	dock - pobj
# 			commercial - amod
# 		fisherman - compound
# 		Charles - compound
# 	Robin - poss
# 		’s - case
# 		small - amod
# 	boat - compound
# dock - pobj
# 	At - prep
# 			Shell - compound
# 		Beach - pobj
# 				just - advmod
# 			two - nummod
# 		miles - npadvmod
# 	from - prep
# 					commercial - amod
# 				fisherman - compound
# 				Charles - compound
# 			Robin - poss
# 				’s - case
# 				small - amod
# 			boat - compound
# 		dock - pobj
# 		the - det
# 	sea - nsubj
# 	has - aux
# risen - ROOT
# 			about - advmod
# 		seven - nummod
# 	inches - dobj
# 	since - prep
# 		2009 - pobj
# 	according - prep
# 		to - prep
# 			data - pobj
# 				from - prep
# 						the - det
# 						National - compound
# 					Oceanic - pobj
# 						and - cc
# 							Atmospheric - compound
# 						Administration - conj
# since - prep
# 	2009 - pobj
# from - prep
# 		the - det
# 		National - compound
# 	Oceanic - pobj
# 		and - cc
# 			Atmospheric - compound
# 		Administration - conj
# with - prep
# 		the - det
# 		U.S. - compound
# 		Geological - compound
# 	Survey - pobj
# 		and - cc
# 			the - det
# 		state - conj
# 	Louisiana - poss
# 		’s - case
# wetlands - dobj
# 		nearly - advmod
# 	400 - nummod
# 	sampling - amod
# stations - dobj
# 		each - det
# 		a - det
# 		square - amod
# 	kilometer - appos
# 		in - prep
# 			size - pobj
# 		nearly - advmod
# 	400 - nummod
# 	sampling - amod
# stations - dobj
# 		each - det
# 		a - det
# 		square - amod
# 	kilometer - appos
# 		in - prep
# 			size - pobj
# near - prep
# 		the - det
# 	Gulf - pobj
# 		of - prep
# 			Mexico - pobj
# since - prep
# 	around - prep
# 		2015 - pobj
# 	Chart - nsubj
# shows - ROOT
# 		estuarine - compound
# 	marshes - dobj
# 		in - prep
# 				the - det
# 				Terrebonne - nmod
# 			Barataria - pobj
# 					Breton - compound
# 				Sound - conj
# 					and - cc
# 						Pontchartrain - compound
# 					basins - conj
# 	the - det
# 	Terrebonne - nmod
# Barataria - pobj
# 		Breton - compound
# 	Sound - conj
# 		and - cc
# 			Pontchartrain - compound
# 		basins - conj
# in - prep
# 		the - det
# 		Terrebonne - nmod
# 	Barataria - pobj
# 			Breton - compound
# 		Sound - conj
# 			and - cc
# 				Pontchartrain - compound
# 			basins - conj
# 	the - det
# 	Terrebonne - nmod
# Barataria - pobj
# 		Breton - compound
# 	Sound - conj
# 		and - cc
# 			Pontchartrain - compound
# 		basins - conj
# 	Pontchartrain - compound
# basins - conj
# Couvillion - appos
# 	B.R. - appos
# 	2023 - appos
# Couvillion - appos
# 	B.R. - appos
# 	2023 - appos
# 	Source - nsubj
# 		Couvillion - appos
# 			B.R. - appos
# 			2023 - appos
# 	Chart - nsubj
# shows - ROOT
# 	saltwater - dobj
# 		and - cc
# 		brackish - conj
# 			marshes - dobj
# 	in - prep
# 			the - det
# 			Terrebonne - nmod
# 		Barataria - pobj
# 				Breton - compound
# 			Sound - conj
# 				and - cc
# 					Pontchartrain - compound
# 				basins - conj
# 	the - det
# 	Terrebonne - nmod
# Barataria - pobj
# 		Breton - compound
# 	Sound - conj
# 		and - cc
# 			Pontchartrain - compound
# 		basins - conj
# in - prep
# 		the - det
# 		Terrebonne - nmod
# 	Barataria - pobj
# 			Breton - compound
# 		Sound - conj
# 			and - cc
# 				Pontchartrain - compound
# 			basins - conj
# 	the - det
# 	Terrebonne - nmod
# Barataria - pobj
# 		Breton - compound
# 	Sound - conj
# 		and - cc
# 			Pontchartrain - compound
# 		basins - conj
# 	Pontchartrain - compound
# basins - conj
# for - prep
# 		six - nummod
# 			or - cc
# 			seven - conj
# 	years - pobj
# 		Source - dep
# 			Brady - compound
# 		Couvillion - dep
#
#  - dep
# 		This - nsubj
# 		is - aux
# 	becoming - ccomp
# 			a - det
# 		trend - attr
# 				that - dobj
# 				we - nsubj
# 				’ve - aux
# 			seen - relcl
# 				for - prep
# 						six - nummod
# 							or - cc
# 							seven - conj
# 					years - pobj
# 				now - advmod
# said - ROOT
# 		Brady - compound
# 	Couvillion - nsubj
# 			a - det
# 			coastal - amod
# 		geographer - appos
# 			with - prep
# 					the - det
# 					U.S. - compound
# 					Geological - compound
# 				Survey - pobj
# 						who - nsubj
# 					charts - relcl
# 							the - det
# 							wetland - amod
# 						changes - dobj
# with - prep
# 		the - det
# 		U.S. - compound
# 		Geological - compound
# 	Survey - pobj
# 			who - nsubj
# 		charts - relcl
# 				the - det
# 				wetland - amod
# 			changes - dobj
# at - prep
# 		Tulane - compound
# 	University - pobj
# 		more - amod
# 		than - quantmod
# 	200 - nummod
# 		wetland - amod
# 	monitoring - compound
# stations - pobj
# changes - dobj
# 	between - prep
# 		2009 - pobj
# 			and - cc
# 			2021 - conj
# 			The - det
# 		number - nsubj
# 			of - prep
# 					the - det
# 					drowning - nmod
# 				sites - pobj
# 	is - ccomp
# 			much - advmod
# 		more - acomp
# 				than - mark
# 				I - nsubj
# 			thought - advcl
# 					before - mark
# 					I - nsubj
# 				started - advcl
# 						the - det
# 					research - dobj
# said - ROOT
# 		Guandong - compound
# 	Li - nsubj
# 			a - det
# 			PhD - compound
# 		student - appos
# 			at - prep
# 				Tulane - pobj
# 				who - nsubj
# 			led - relcl
# 					the - det
# 				work - dobj
# 	a - det
# 	PhD - compound
# student - appos
# 	at - prep
# 		Tulane - pobj
# 		who - nsubj
# 	led - relcl
# 			the - det
# 		work - dobj
# at - prep
# 	Tulane - pobj
# 			About - advmod
# 		90 - nummod
# 	percent - nsubj
# 		of - prep
# 				these - det
# 			sites - pobj
# are - ROOT
# 	unable - acomp
# 			to - aux
# 		keep - xcomp
# 			up - prt
# 			with - prep
# 					this - det
# 					recent - amod
# 					high - amod
# 				rate - pobj
# 					of - prep
# 								sea - compound
# 							level - compound
# 						rise - pobj
# 	This - det
# spring - ROOT
# 		a - det
# 	group - appos
# 		of - prep
# 			Louisianans - pobj
# 			who - nsubj
# 			have - aux
# 		seen - relcl
# 				the - det
# 				rapid - amod
# 			changes - dobj
# 				gathered - acl
# 					for - prep
# 							a - det
# 							crawfish - amod
# 						boil - pobj
# 							in - prep
# 								Yscloskey - pobj
# 		near - prep
# 				large - amod
# 			stretches - pobj
# 				of - prep
# 						skeletal - amod
# 						oak - compound
# 					trees - pobj
# 						killed - acl
# 							by - prep
# 								encroaching - pcomp
# 										salt - compound
# 									water - dobj
# of - prep
# 	Louisianans - pobj
# in - prep
# 	Yscloskey - pobj
# 		Polly - compound
# 	Glover - nsubjpass
# 			whose - poss
# 		life - nmod
# 			and - cc
# 			family - conj
# 	history - nsubjpass
# 	are - auxpass
# entwined - ROOT
# 	with - prep
# 				the - det
# 			state - poss
# 				’s - case
# 		wetlands - pobj
# 		has - aux
# 	crisscrossed - conj
# 		Louisiana - dobj
# 		trying - advcl
# 				to - aux
# 			restore - xcomp
# 				them - dobj
# 				by - prep
# 						planting - compound
# 					grasses - pobj
# 	has - aux
# crisscrossed - conj
# 	Louisiana - dobj
# 	trying - advcl
# 			to - aux
# 		restore - xcomp
# 			them - dobj
# 			by - prep
# 					planting - compound
# 				grasses - pobj
# 	oyster - compound
# farmer - appos
# 	and - cc
# 	shrimper - conj
# 		George - compound
# 	Barisich - appos
# protecting - pcomp
# 		New - compound
# 	Orleans - dobj
# of - prep
# 		the - det
# 		Barataria - compound
# 	Basin - pobj
# 	the - det
# 	middle - amod
# part - dobj
# 	of - prep
# 			the - det
# 			Barataria - compound
# 		Basin - pobj
# 	and - cc
# 		the - det
# 		lower - amod
# 		Breton - compound
# 		Sound - compound
# 	Basin - conj
# 	on - prep
# 			either - det
# 		side - pobj
# 			of - prep
# 					the - det
# 					Mississippi - compound
# 				River - pobj
# of - prep
# 		the - det
# 		Mississippi - compound
# 	River - pobj
# of - prep
# 		middle - amod
# 	Barataria - pobj
# 		The - det
# 	wetlands - nsubj
# 		of - prep
# 				middle - amod
# 			Barataria - pobj
# 	are - aux
# shrinking - ROOT
# 			faster - advmod
# 			than - quantmod
# 		75 - nummod
# 	percent - dobj
# 		of - prep
# 				all - det
# 				other - amod
# 				Louisiana - compound
# 				wetland - compound
# 			regions - pobj
# 	according - prep
# 		to - prep
# 			Couvillion - pobj
# 	with - prep
# 			the - det
# 			pace - compound
# 		quickening - pobj
# 			in - prep
# 					recent - amod
# 				years - pobj
# 	all - det
# 	other - amod
# 	Louisiana - compound
# 	wetland - compound
# regions - pobj
# to - prep
# 	Couvillion - pobj
# in - prep
# 		recent - amod
# 	years - pobj
# 	the - det
# 	lower - amod
# 		Breton - compound
# 	Sound - compound
# region - pobj
# 			More - amod
# 			than - quantmod
# 		8,700 - nummod
# 	acres - nsubj
# 	have - aux
# vanished - ROOT
# 	since - prep
# 		1985 - pobj
# 	according - prep
# 		to - prep
# 				USGS - compound
# 			estimates - pobj
# 	and - cc
# 		much - nsubj
# 			of - prep
# 					that - det
# 				loss - pobj
# 		has - aux
# 	come - conj
# 		over - prep
# 				the - det
# 				past - amod
# 			decade - pobj
# since - prep
# 	1985 - pobj
# 	USGS - compound
# estimates - pobj
# over - prep
# 		the - det
# 		past - amod
# 	decade - pobj
# Map - ROOT
# 	comparing - acl
# 			the - det
# 		extent - dobj
# 			of - prep
# 				wetlands - pobj
# 					in - prep
# 								the - det
# 								Breton - compound
# 							Sound - nmod
# 								and - cc
# 									Mid - compound
# 								Barataria - conj
# 						regions - pobj
# 							to - prep
# 									the - det
# 									south - compound
# 								east - pobj
# 									of - prep
# 											New - compound
# 										Orleans - pobj
# 		in - prep
# 			1985 - pobj
# 				and - cc
# 				2020 - conj
#
#
#  - dep
# 		the - det
# 		Breton - compound
# 	Sound - nmod
# 		and - cc
# 			Mid - compound
# 		Barataria - conj
# regions - pobj
# 	to - prep
# 			the - det
# 			south - compound
# 		east - pobj
# 			of - prep
# 					New - compound
# 				Orleans - pobj
# of - prep
# 		New - compound
# 	Orleans - pobj
# in - prep
# 	1985 - pobj
# 		and - cc
# 		2020 - conj
#
#
#  - dep
# 1985 - pobj
# 	and - cc
# 	2020 - conj
#
#
#  - dep
# 	Louisiana - poss
# 		’s - case
# wetlands - nsubj
# by - agent
# 	Katrina - pobj
# 		and - cc
# 			other - amod
# 		hurricanes - conj
# in - prep
# 		the - det
# 	2000s - pobj
# by - prep
# 	2010 - pobj
# 		The - det
# 	trend - nsubj
# reversed - ROOT
# 				about - advmod
# 			five - nummod
# 		years - npadvmod
# 	later - advmod
# 	suggesting - advcl
# 				the - det
# 				sudden - amod
# 			bout - nsubj
# 				of - prep
# 							sea - compound
# 						level - compound
# 					rise - pobj
# 			could - aux
# 		be - ccomp
# 				a - det
# 				major - amod
# 			factor - attr
# In - prep
# 		middle - amod
# 	Barataria - pobj
# 	the - det
# 	current - amod
# 		Gulf - compound
# 	Coast - compound
# surge - pobj
# In - prep
# 	2012 - pobj
# 	In - prep
# 		2012 - pobj
# 	Louisiana - nsubj
# projected - ROOT
# 		that - mark
# 			if - mark
# 				sea - compound
# 			level - compound
# 		rise - nsubj
# 			and - cc
# 				other - amod
# 				environmental - amod
# 			threats - conj
# 	remain - ccomp
# 		modest - acomp
# 		it - nsubj
# 		would - aux
# 	be - conj
# 		able - acomp
# 				to - aux
# 			rebuild - xcomp
# 				land - dobj
# 				within - prep
# 						50 - nummod
# 					years - pobj
# within - prep
# 		50 - nummod
# 	years - pobj
# released - acl
# 		this - det
# 	year - npadvmod
# by - prep
# 		late - advmod
# 		this - det
# 	century - pobj
# Over - prep
# 		the - det
# 	period - pobj
# 		of - prep
# 				10 - nummod
# 			years - pobj
# 		Over - prep
# 				the - det
# 			period - pobj
# 				of - prep
# 						10 - nummod
# 					years - pobj
# 			the - det
# 		state - nsubj
# 		has - aux
# 	gone - ccomp
# 		from - prep
# 				potentially - advmod
# 			being - pcomp
# 				in - prep
# 						a - det
# 						net - amod
# 						gain - compound
# 					situation - pobj
# 		to - prep
# 				potentially - advmod
# 			being - pcomp
# 				in - prep
# 						a - det
# 							very - advmod
# 						significant - amod
# 						net - amod
# 						loss - compound
# 					situation - pobj
# said - ROOT
# 		Alex - compound
# 	Kolker - nsubj
# 			a - det
# 			coastal - amod
# 		geologist - appos
# 			with - prep
# 					the - det
# 						Louisiana - compound
# 					Universities - compound
# 					Marine - compound
# 				Consortium - pobj
# with - prep
# 		the - det
# 			Louisiana - compound
# 		Universities - compound
# 		Marine - compound
# 	Consortium - pobj
# 			The - det
# 		science - nsubj
# 			behind - prep
# 					the - det
# 					coastal - amod
# 					planning - compound
# 				process - pobj
# 		has - aux
# 	gotten - ccomp
# 		better - acomp
# said - ROOT
# 		Greg - compound
# 	Grandy - nsubj
# 			deputy - amod
# 			executive - amod
# 		director - appos
# 			of - prep
# 						the - det
# 					state - poss
# 						’s - case
# 						Coastal - nmod
# 					Protection - nmod
# 						and - cc
# 						Restoration - conj
# 				Authority - pobj
# of - prep
# 			the - det
# 		state - poss
# 			’s - case
# 			Coastal - nmod
# 		Protection - nmod
# 			and - cc
# 			Restoration - conj
# 	Authority - pobj
# in - prep
# 	2012 - pobj
# 			Over - prep
# 				time - pobj
# 				the - det
# 			sea - nsubj
# 			has - aux
# 		risen - ccomp
# 		so - advmod
# 		we - nsubj
# 		’re - aux
# 		not - neg
# 	talking - ccomp
# 		about - prep
# 				the - det
# 				same - amod
# 				environmental - amod
# 			conditions - pobj
# 			that - dep
# 			we - nsubj
# 			were - aux
# 		talking - advcl
# 			about - prep
# 			in - prep
# 				2012 - pobj
# 	Grandy - nsubj
# added - ROOT
# 	Louisiana - nsubj
# 	still - advmod
# thinks - ROOT
# 			its - poss
# 		plans - nsubj
# 		will - aux
# 	make - ccomp
# 			a - det
# 		difference - dobj
# 	One - nsubj
# 		of - prep
# 				the - det
# 				largest - amod
# 			projects - pobj
# 	would - aux
# use - ROOT
# 		the - det
# 		Mississippi - compound
# 	River - dobj
# 				whose - poss
# 			sediments - nsubj
# 		built - relcl
# 			much - dobj
# 				of - prep
# 						coastal - amod
# 					Louisiana - pobj
# 		to - aux
# 	rebuild - xcomp
# 		wetlands - dobj
# 	One - nsubj
# 		of - prep
# 				the - det
# 				largest - amod
# 			projects - pobj
# 	would - aux
# use - ROOT
# 		the - det
# 		Mississippi - compound
# 	River - dobj
# 				whose - poss
# 			sediments - nsubj
# 		built - relcl
# 			much - dobj
# 				of - prep
# 						coastal - amod
# 					Louisiana - pobj
# 		to - aux
# 	rebuild - xcomp
# 		wetlands - dobj
# of - prep
# 		coastal - amod
# 	Louisiana - pobj
# including - prep
# 	Barisich - pobj
# 		and - cc
# 		Robin - conj
# Barisich - pobj
# 	and - cc
# 	Robin - conj
# including - prep
# 	Glover - pobj
# 		and - cc
# 			the - det
# 			local - amod
# 		nonprofit - conj
# 	she - nsubj
# works - relcl
# 	with - prep
# 	Restore - conj
# 		or - cc
# 		Retreat - conj
# 	that - nsubj
# is - relcl
# 	Louisiana - attr
# 	where - advmod
# 		the - det
# 		Mississippi - compound
# 	River - nsubj
# spills - pcomp
# 	into - prep
# 			the - det
# 		gulf - pobj
# 		earlier - advmod
# 		this - det
# 	year - npadvmod
# into - prep
# 		the - det
# 	gulf - pobj
# 	where - advmod
# 		the - det
# 		Mississippi - compound
# 	River - nsubj
# spills - pcomp
# 	into - prep
# 			the - det
# 		gulf - pobj
# 		earlier - advmod
# 		this - det
# 	year - npadvmod
# to - prep
# 		Bayou - compound
# 	Lamoque - pobj
# 			a - det
# 		place - appos
# 				she - nsubj
# 				had - aux
# 				never - neg
# 			visited - relcl
# 			where - advmod
# 				her - poss
# 				family - compound
# 			history - nsubj
# 				and - cc
# 				Louisiana - conj
# 					’s - case
# 		plans - relcl
# 				to - aux
# 			save - xcomp
# 				itself - dobj
# 	her - poss
# 	family - compound
# history - nsubj
# 	and - cc
# 	Louisiana - conj
# 		’s - case
# 	Glover - poss
# 		’s - case
# father - nsubj
# in - prep
# 	2007 - pobj
# 		engineer - compound
# 		John - compound
# 		Edgar - compound
# 	Land - nsubj
# 	had - aux
# been - conj
# 		a - det
# 		longtime - amod
# 		state - compound
# 	employee - attr
# 	But - cc
# 	it - nsubj
# was - ROOT
# 	n’t - neg
# 	until - prep
# 			last - amod
# 		year - pobj
# 		that - advmod
# 		she - nsubj
# 	learned - ccomp
# 			he - nsubjpass
# 			’d - aux
# 			apparently - advmod
# 			been - auxpass
# 		involved - ccomp
# 			in - prep
# 				designing - pcomp
# 							the - det
# 						state - poss
# 							’s - case
# 						first - amod
# 						large - amod
# 						engineered - amod
# 							river - compound
# 						diversion - compound
# 					project - dobj
# 		constructed - advcl
# 				long - advmod
# 			before - advmod
# 					the - det
# 					current - amod
# 				race - pobj
# 						to - aux
# 					defend - relcl
# 							the - det
# 						coast - dobj
# until - prep
# 		last - amod
# 	year - pobj
# 		the - det
# 	state - poss
# 		’s - case
# 	first - amod
# 	large - amod
# 	engineered - amod
# 		river - compound
# 	diversion - compound
# project - dobj
# 	In - prep
# 			an - det
# 			old - amod
# 		box - pobj
# 				she - nsubj
# 			found - relcl
# 				in - prep
# 							her - poss
# 						brother - poss
# 							’s - case
# 					house - pobj
# 	Glover - nsubj
# discovered - ROOT
# 	plans - dobj
# 		for - prep
# 				the - det
# 					Bayou - compound
# 					Lamoque - compound
# 				Freshwater - compound
# 			Diversion - pobj
# for - prep
# 		the - det
# 			Bayou - compound
# 			Lamoque - compound
# 		Freshwater - compound
# 	Diversion - pobj
# in - prep
# 		the - det
# 	mid-1950s - pobj
# 	to - aux
# channel - xcomp
# 	up - prt
# 			to - quantmod
# 		4,000 - nummod
# 		cubic - amod
# 	feet - dobj
# 		of - prep
# 				fresh - amod
# 			water - pobj
# 	per - prep
# 		second - pobj
# 	into - prep
# 			the - det
# 		marshes - pobj
# 			behind - prep
# 				it - pobj
# per - prep
# 	second - pobj
# 	Louisiana - compound
#
#
#  - dep
# 		New - compound
#
#  - dep
# 	Orleans - compound
#
#  - dep
# 	Detail - compound
#
#  - dep
# Map - pobj
# 	Louisiana - compound
#
#
#  - dep
# 		New - compound
#
#  - dep
# 	Orleans - compound
#
#  - dep
# 	Detail - compound
#
#  - dep
# Map - pobj
# 	Louisiana - compound
#
#
#  - dep
# 		New - compound
#
#  - dep
# 	Orleans - compound
#
#  - dep
# 	Detail - compound
#
#  - dep
# Map - pobj
# in - prep
# 		the - det
# 	1950s - pobj
# between - prep
# 		the - det
# 		Mississippi - compound
# 	River - pobj
# 		and - cc
# 			Breton - nmod
# 			Sound - nmod
#
#  - dep
# 		BRETON - conj
#
#  - dep
# 	Breton - nmod
# 	Sound - nmod
#
#  - dep
# BRETON - conj
#
#  - dep
# 	the - det
# 	1950s - nummod
#
#  - dep
# 		1 - prep
# 	MILE - compound
#
#  - dep
# Source - pobj
# 	the - det
# 	1950s - nummod
#
#  - dep
# 		1 - prep
# 	MILE - compound
#
#  - dep
# Source - pobj
# 		Planet - compound
# 	Labs - compound
# PBC - pobj
#
#  - dep
# 		Locator - compound
# 	map - nsubj
# 			that - nsubj
# 		shows - relcl
# 				the - det
# 			location - dobj
# 				of - prep
# 						the - det
# 						following - amod
# 					map - pobj
# 						within - prep
# 								Louisiana - compound
#
#
#  - dep
# 									New - compound
#
#  - dep
# 								Orleans - compound
#
#  - dep
# 								Detail - compound
#
#  - dep
# 							Map - pobj
# 						showing - acl
# 								the - det
# 							location - dobj
# 								of - prep
# 										a - det
# 										freshwater - compound
# 									diversion - pobj
# 										built - acl
# 											in - prep
# 													the - det
# 												1950s - pobj
# 											between - prep
# 													the - det
# 													Mississippi - compound
# 												River - pobj
# 													and - cc
# 														Breton - nmod
# 														Sound - nmod
#
#  - dep
# 													BRETON - conj
#
#  - dep
# 								SOUND - amod
#
#  - dep
# 								Freshwater - compound
# 							diversion - dobj
#
#  - dep
# 								built - acl
# 									in - prep
# 											the - det
# 											1950s - nummod
#
#  - dep
# 												1 - prep
# 											MILE - compound
#
#  - dep
# 										Source - pobj
# 			Satellite - compound
# 		imagery - appos
# 			via - prep
# 						Planet - compound
# 					Labs - compound
# 				PBC - pobj
#
#  - dep
# 	Today - npadvmod
# 		the - det
# 	diversion - nsubj
# is - ROOT
# 	in - prep
# 		disrepair - pobj
# 		apparently - advmod
# 	clogged - advcl
# 		with - prep
# 				so - advmod
# 			much - amod
# 			Mississippi - compound
# 		River - nsubj
# 	silt - dep
# 			you - nsubj
# 			can - aux
# 		walk - ccomp
# 			around - prep
# 				it - pobj
# 			so - advmod
# 		much - amod
# 		Mississippi - compound
# 	River - nsubj
# silt - dep
# 		you - nsubj
# 		can - aux
# 	walk - ccomp
# 		around - prep
# 			it - pobj
# 	Land - poss
# 		’s - case
# name - nsubj
# 	Glover - nsubj
# says - conj
# 		she - nsubj
# 	recognizes - ccomp
# 			the - det
# 		handwriting - dobj
# 	Louisiana - nsubj
# 	is - aux
# planning - ROOT
# 		two - nummod
# 				far - advmod
# 			more - advmod
# 		massive - amod
# 	diversions - dobj
# 	one - npadvmod
# 		channeling - acl
# 				the - det
# 				Mississippi - compound
# 			west - dobj
# 			into - prep
# 					the - det
# 					struggling - amod
# 				marshes - pobj
# 					of - prep
# 						Barataria - pobj
# 							and - cc
# 				another - nsubj
# 			pouring - conj
# 						fresh - amod
# 					water - compound
# 				east - advmod
# 				into - prep
# 						the - det
# 							equally - advmod
# 						imperiled - amod
# 					wetlands - pobj
# 						of - prep
# 								Breton - compound
# 							Sound - pobj
# 	two - nummod
# 			far - advmod
# 		more - advmod
# 	massive - amod
# diversions - dobj
# 	Louisiana - nsubj
# 	is - aux
# planning - ROOT
# 		two - nummod
# 				far - advmod
# 			more - advmod
# 		massive - amod
# 	diversions - dobj
# 	one - npadvmod
# 		channeling - acl
# 				the - det
# 				Mississippi - compound
# 			west - dobj
# 			into - prep
# 					the - det
# 					struggling - amod
# 				marshes - pobj
# 					of - prep
# 						Barataria - pobj
# 							and - cc
# 				another - nsubj
# 			pouring - conj
# 						fresh - amod
# 					water - compound
# 				east - advmod
# 				into - prep
# 						the - det
# 							equally - advmod
# 						imperiled - amod
# 					wetlands - pobj
# 						of - prep
# 								Breton - compound
# 							Sound - pobj
# 	the - det
# 	Mississippi - compound
# west - dobj
# of - prep
# 	Barataria - pobj
# 		and - cc
# of - prep
# 		Breton - compound
# 	Sound - pobj
# 	the - det
# 	first - amod
# project - pobj
# in - prep
# 	mid - pobj
# 	Barataria - pobj
# 	to - aux
# begin - xcomp
# 	Tuesday - npadvmod
# 	The - det
# 	mid - compound
# 	Barataria - amod
# diversion - nsubj
# 		The - det
# 		mid - compound
# 		Barataria - amod
# 	diversion - nsubj
# 	will - aux
# cost - ROOT
# 		$ - quantmod
# 		2.9 - compound
# 	billion - dobj
# 	and - cc
# 	channel - conj
# 			enormous - amod
# 		volumes - dobj
# 			of - prep
# 				water - pobj
# 		up - advmod
# 					to - quantmod
# 				75,000 - nummod
# 				cubic - amod
# 			feet - pobj
# 				per - prep
# 					second - pobj
# up - advmod
# 			to - quantmod
# 		75,000 - nummod
# 		cubic - amod
# 	feet - pobj
# 		per - prep
# 			second - pobj
# 	the - det
# 	two - nummod
# diversions - nsubj
# 	Together - advmod
# 		the - det
# 		two - nummod
# 	diversions - nsubj
# are - ROOT
# 	one - attr
# 		of - prep
# 				the - det
# 				core - compound
# 			components - pobj
# 				of - prep
# 							the - det
# 						state - poss
# 							’s - case
# 							Coastal - compound
# 						Master - compound
# 					Plan - pobj
#
#
#  - dep
# 	A - det
# 	linked - amod
# fate - npadvmod
#
#  - dep
# 	Today - npadvmod
# 		New - compound
# 	Orleans - poss
# 		’s - case
# 		coastal - amod
# 	barrier - compound
# system - nsubjpass
# 	recently - advmod
# withstood - conj
# 		Hurricane - compound
# 	Ida - dobj
# 			a - det
# 			powerful - amod
# 			Category - nmod
# 				4 - nummod
# 		storm - appos
# 	without - prep
# 			being - auxpass
# 		overtopped - pcomp
# 	a - det
# 	powerful - amod
# 	Category - nmod
# 		4 - nummod
# storm - appos
# 	And - cc
# 		no - neg
# 	matter - advmod
# 				how - advmod
# 			high - acomp
# 				the - det
# 			barriers - nsubj
# 		are - ccomp
# 		New - compound
# 	Orleans - nsubj
# 	will - aux
# be - ROOT
# 		less - advmod
# 	safe - acomp
# 		if - mark
# 			the - det
# 		wetlands - nsubj
# 			and - cc
# 				the - det
# 				fishing - compound
# 			communities - conj
# 			the - det
# 		city - nsubj
# 	depends - advcl
# 		on - prep
# 			disappear - pobj
# 		Austin - compound
# 	Feldbaum - nsubj
# heads - ROOT
# 	up - prt
# 		hazard - compound
# 	mitigation - dobj
# 	at - prep
# 				New - compound
# 			Orleans - poss
# 				’s - case
# 		Office - pobj
# 			of - prep
# 					Homeland - compound
# 				Security - pobj
# 					and - cc
# 						Emergency - compound
# 					Preparedness - conj
# at - prep
# 			New - compound
# 		Orleans - poss
# 			’s - case
# 	Office - pobj
# 		of - prep
# 				Homeland - compound
# 			Security - pobj
# 				and - cc
# 					Emergency - compound
# 				Preparedness - conj
# 	Homeland - compound
# Security - pobj
# 	and - cc
# 		Emergency - compound
# 	Preparedness - conj
# 		And - cc
# 			as - mark
# 			seas - nsubj
# 		continue - advcl
# 				to - aux
# 			rise - xcomp
# 			the - det
# 		impacts - nsubjpass
# 		will - aux
# 		not - neg
# 		be - auxpass
# 	borne - ccomp
# 		equally - advmod
# said - ROOT
# 		Michael - compound
# 	Esealuka - nsubj
# 			an - det
# 			environmental - amod
# 			justice - compound
# 		organizer - appos
# 			in - prep
# 				Louisiana - pobj
# in - prep
# 	Louisiana - pobj
# About - ROOT
# 		this - det
# 		story - compound
#
#  - dep
# 	Design - pobj
# 		and - cc
# 		development - conj
# 		by - prep
# 				Hailey - compound
# 			Haymond - pobj
# by - prep
# 		Hailey - compound
# 	Haymond - pobj
# by - prep
# 		Katie - compound
# 	Zezima - pobj
# 			Angela - compound
# 			M. - compound
# 		Hill - conj
# 				Amanda - compound
# 			Voisard - conj
# 				Joe - compound
# 			Moore - conj
# 				and - cc
# 					Monica - compound
# 				Ulmanu - conj
# 	Katie - compound
# Zezima - pobj
# 		Angela - compound
# 		M. - compound
# 	Hill - conj
# 			Amanda - compound
# 		Voisard - conj
# 			Joe - compound
# 		Moore - conj
# 			and - cc
# 				Monica - compound
# 			Ulmanu - conj
# 	Angela - compound
# 	M. - compound
# Hill - conj
# 		Amanda - compound
# 	Voisard - conj
# 		Joe - compound
# 	Moore - conj
# 		and - cc
# 			Monica - compound
# 		Ulmanu - conj
# 	Angela - compound
# 	M. - compound
# Hill - conj
# 		Amanda - compound
# 	Voisard - conj
# 		Joe - compound
# 	Moore - conj
# 		and - cc
# 			Monica - compound
# 		Ulmanu - conj
# 	Joe - compound
# Moore - conj
# 	and - cc
# 		Monica - compound
# 	Ulmanu - conj
# by - prep
# 		Emily - compound
# 	Morman - pobj
# 	Louisiana - compound
# 	wetland - compound
# changes - pobj
# 		Brady - compound
# 	Couvillion - poss
# 		’s - case
# work - pobj
# 	on - prep
# 		behalf - pobj
# 			of - prep
# 					the - det
# 					2023 - nummod
# 					Draft - compound
# 					Coastal - compound
# 					Master - compound
# 				Plan - pobj
# 						Attachment - compound
# 					D6 - appos
# 	the - det
# 	2023 - nummod
# 	Draft - compound
# 	Coastal - compound
# 	Master - compound
# Plan - pobj
# 		Attachment - compound
# 	D6 - appos
# of - prep
# 		the - det
# 		2023 - nummod
# 		Draft - compound
# 		Coastal - compound
# 		Master - compound
# 	Plan - pobj
# 			Attachment - compound
# 		D6 - appos
# 			Louisiana - compound
# 		State - nmod
# 	University - nmod
# 	doctoral - amod
# candidate - compound
# 					Louisiana - compound
# 				State - nmod
# 			University - nmod
# 			doctoral - amod
# 		candidate - compound
# 		Daena - compound
# 	Carrillo - nsubj
# shared - ROOT
# 			John - compound
# 			Edgar - compound
# 		Land - poss
# 			’s - case
# 	plans - dobj
# 		and - cc
# 		papers - conj
# 		John - compound
# 		Edgar - compound
# 	Land - poss
# 		’s - case
# plans - dobj
# 	and - cc
# 	papers - conj
# 		Don - compound
# 	Davis - nsubj
# 				Louisiana - compound
# 			Sea - compound
# 			Grant - compound
# 		scholar - appos
# provided - ROOT
# 		historical - amod
# 	research - dobj
# 		on - prep
# 				the - det
# 					Bayou - compound
# 					Lamoque - compound
# 				Freshwater - compound
# 			Diversion - pobj
# 		Louisiana - compound
# 	Sea - compound
# 	Grant - compound
# scholar - appos
# on - prep
# 		the - det
# 			Bayou - compound
# 			Lamoque - compound
# 		Freshwater - compound
# 	Diversion - pobj
# in - prep
# 	1985 - pobj
# 		and - cc
# 		2020 - conj
# 1985 - pobj
# 	and - cc
# 	2020 - conj
# 	5 - nummod
# imagery - dobj
# 		The - det
# 	map - nsubj
# 		comparing - acl
# 			wetlands - dobj
# 			in - prep
# 				1985 - pobj
# 					and - cc
# 					2020 - conj
# uses - ROOT
# 			cloud - npadvmod
# 		free - amod
# 	mosaics - dobj
# 		of - prep
# 			Landsat - pobj
# 		5 - nummod
# 	imagery - dobj
# 	from - prep
# 		June - pobj
# 			1984 - nummod
# 	to - prep
# 		June - pobj
# 			1986 - nummod
# 	and - cc
# 	Landsat - conj
# 			8 - nummod
# 		imagery - npadvmod
# 		from - prep
# 			2020 - pobj
# 		The - det
# 	map - nsubj
# 		comparing - acl
# 			wetlands - dobj
# 			in - prep
# 				1985 - pobj
# 					and - cc
# 					2020 - conj
# uses - ROOT
# 			cloud - npadvmod
# 		free - amod
# 	mosaics - dobj
# 		of - prep
# 			Landsat - pobj
# 		5 - nummod
# 	imagery - dobj
# 	from - prep
# 		June - pobj
# 			1984 - nummod
# 	to - prep
# 		June - pobj
# 			1986 - nummod
# 	and - cc
# 	Landsat - conj
# 			8 - nummod
# 		imagery - npadvmod
# 		from - prep
# 			2020 - pobj
# from - prep
# 	2020 - pobj
# 	Landsat - npadvmod
# derived - amod
# from - prep
# 	Couvillion - pobj

# %%
# Displacy for Entity Dependencies

entity_spans = list(wapo_proc.ents)
displacy.render(entity_spans, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4a00b1a4fb624b13b42f8a372f80848f-0" class="displacy" width="225" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">SURGE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
# </svg>
#
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4a00b1a4fb624b13b42f8a372f80848f-1" class="displacy" width="575" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">New</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Orleans</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PART</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4a00b1a4fb624b13b42f8a372f80848f-1-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4a00b1a4fb624b13b42f8a372f80848f-1-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4a00b1a4fb624b13b42f8a372f80848f-1-1" stroke-width="2px" d="M245,89.5 C245,2.0 400.0,2.0 400.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4a00b1a4fb624b13b42f8a372f80848f-1-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,91.5 L408.0,79.5 392.0,79.5" fill="currentColor"/>
# </g>
# </svg>
#
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4a00b1a4fb624b13b42f8a372f80848f-2" class="displacy" width="400" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">ByChris</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Mooney</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4a00b1a4fb624b13b42f8a372f80848f-2-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4a00b1a4fb624b13b42f8a372f80848f-2-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
# </svg>
#
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4a00b1a4fb624b13b42f8a372f80848f-3" class="displacy" width="400" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Zoeann</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Murphy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4a00b1a4fb624b13b42f8a372f80848f-3-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4a00b1a4fb624b13b42f8a372f80848f-3-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
# </svg>
#
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4a00b1a4fb624b13b42f8a372f80848f-4" class="displacy" width="400" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Ricky</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Carioti</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4a00b1a4fb624b13b42f8a372f80848f-4-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4a00b1a4fb624b13b42f8a372f80848f-4-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
# </svg>
#
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4a00b1a4fb624b13b42f8a372f80848f-5" class="displacy" width="400" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">John</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Muyskens</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4a00b1a4fb624b13b42f8a372f80848f-5-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em;

# %%
# Download larger language model

# !python -m spacy download en_core_web_md
# Out:
# 2023-08-08 14:15:30.297944: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Collecting en-core-web-md==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.6.0/en_core_web_md-3.6.0-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 22.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from en-core-web-md==3.6.0) (3.6.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.10.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.12)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (22.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.28.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (5.2.1)
# Requirement already satisfied: pathy>=0.10.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.10.2)
# Requirement already satisfied: setuptools in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (65.6.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.9.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.4.7)
# Requirement already satisfied: jinja2 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (8.1.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.23.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.26.14)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.1.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.7.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/obelisk/anaconda3/lib/python3.10/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.1.1)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
# Building Larger model

nlp_md = sy.load('en_core_web_md')  # most_similar() requires word vectors which the small model doesn't make.

wapo_proc_md = nlp_md(wapo)

# %%
# Testing my similarity code

for token in wapo_proc_md:
    if not token.is_stop and not token.is_punct and not token.is_space:
        wapo_proc_md.vocab['token']
        print(token, wapo_proc_md.similarity(token))
# Out:
# FACING -0.0635669715220956
# SURGE 0.33996460301493026
# SCROLL -0.04787773373474156
# CONTINUE -0.00046587897177378923
# fast 0.23261411230251836
# burst 0.07155603006615872
# sea 0.2764892415463895
# level 0.47269041937660966
# rise 0.3871019456881518
# New 0.14639698243437788
# Orleans 0.22123043609458123
# outer 0.31221468488907966
# defenses 0.5262883414954734
# face 0.3334105307036669
# major 0.5707226999475583
# test 0.3240830161677376
# ByChris 0.0
# Mooney -0.10311825334040431
# Zoeann 0.0
# Murphy -0.06392847878883644
# Ricky -0.20926239755067658
# Carioti 0.0
# John 0.004952453752994457
# Muyskens 0.0
# Aug. -0.007202400553221737
# 7 -0.07301485444389434
# 6:00 -0.030024614251573965
# a.m. -0.04500233761154775
# Louisiana 0.28982661272489324
# armed 0.3481510799877616
# seas 0.29421599114341906
# years 0.33615787658274954
# Hurricane 0.25082611568208846
# Katrina 0.05360095599288135
# working 0.6000262124844206
# rebuild 0.4009054029492378
# shrinking 0.698923438540561
# coastline 0.4932534455585331
# factoring 0.7373831993115677
# potential 0.6789340021779904
# dire 0.22589788364714425
# climate 0.5836635314527167
# change 0.5548855650570637
# 2010 0.09048501425090735
# U.S. 0.3346147803277225
# Gulf 0.24810440129186345
# Coast 0.18920941348904063
# seen 0.3166470520556236
# sudden 0.2800107104808511
# burst 0.07155603006615872
# rapid 0.46836389648905785
# sea 0.2764892415463895
# level 0.47269041937660966
# rise 0.3871019456881518
# rates 0.42274328700958513
# scientists 0.5513500054887212
# expect 0.38148443597767834
# late 0.3892944861367746
# century 0.40050936270664417
# center 0.5538872465096162
# lie 0.09303165829403776
# wetlands 0.47573587140788287
# line 0.4592894720178402
# defense 0.5103729605483849
# New 0.14639698243437788
# Orleans 0.22123043609458123
# buffering 0.7823169808875561
# levees 0.2249238200230303
# barriers 0.5770833034428482
# change 0.5548855650570637
# city 0.47182185557923745
# nearby 0.4019590293673784
# coastal 0.5174042745302553
# communities 0.6645277805596421
# greater 0.6856646209820094
# risk 0.3575578693372135
# storms 0.46215098637914714
# Shell 0.1274171701264419
# Beach 0.1311446127172868
# miles 0.1373644074249636
# commercial 0.6774611144452931
# fisherman 0.38602858348477265
# Charles 0.08566438577503253
# Robin -0.07550902035675516
# small 0.5225057070367495
# boat 0.13512739455578668
# dock 0.12623557957444523
# sea 0.2764892415463895
# risen 0.215876673386982
# seven 0.42201097243617325
# inches 0.21926627073407268
# 2009 0.08266618249342701
# according 0.6101119171456958
# data 0.39310487215502626
# National 0.39539796730389964
# Oceanic 0.2261844179161603
# Atmospheric 0.5040969791070493
# Administration 0.5268796242597202
# behalf 0.29256839234116033
# 2023 0.09365086985042638
# Draft 0.11820094708550008
# Coastal 0.3793573359605484
# Master 0.25484048233318474
# Plan 0.06861058996749453
# Attachment 0.6551894938160795
# D6 0.10383232200290937
# Louisiana 0.28982661272489324
# State 0.2671309963753224
# University 0.2630360363792042
# doctoral 0.34220822324864736
# candidate 0.3378026799494691
# Daena 0.0
# Carrillo -0.057749703380412576
# shared 0.42600504736687694
# John 0.004952453752994457
# Edgar -0.08226763822046301
# Land 0.08958191505571234
# plans 0.4307081355096883
# papers 0.3836352961139179
# Don -0.12925334308306832
# Davis 0.028011781282648085
# Louisiana 0.28982661272489324
# Sea 0.1442628698778873
# Grant 0.13530393841582705
# scholar 0.3501856383120605
# provided 0.5696554707275153
# historical 0.6624831072335545
# research 0.5361664186916929
# Bayou 0.11712614881655975
# Lamoque 0.0
# Freshwater 0.5588636355578164
# Diversion 0.7520432849106711
# map 0.23812031105205309
# comparing 0.7091659590436561
# wetlands 0.47573587140788287
# 1985 0.046778856648695626
# 2020 0.04181334179575272
# uses 0.35427168813372245
# cloud 0.316524327388175
# free 0.2877902873615178
# mosaics 0.2108230732323225
# Landsat 0.3368557746209867
# 5 -0.08606772879723429
# imagery 0.3684013179504409
# June 0.0489329132379422
# 1984 0.039283450055004956
# June 0.0489329132379422
# 1986 0.03795060602477717
# Landsat 0.3368557746209867
# 8 -0.05643387717605717
# imagery 0.3684013179504409
# 2020 0.04181334179575272
# satellite 0.39827723558978523
# imagery 0.3684013179504409
# masked 0.15835896435769647
# water 0.452636791650722
# Landsat 0.3368557746209867
# derived 0.46065538101580644
# water 0.452636791650722
# data 0.39310487215502626
# Couvillion 0.0
# /var/folders/h0/3gzsn_d548l8bqt1z1_nhch00000gn/T/ipykernel_72035/330495976.py:4: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   print(token, wapo_proc_md.similarity(token))

# %%
# Similarities as a list

similar = [(token.text, wapo_proc_md.similarity(token)) # It throws an error but it generates the same results when not making an obejct
               for token in wapo_proc_md
                    if not token.is_stop and not token.is_punct and not token.is_space]
# Out:
# /var/folders/h0/3gzsn_d548l8bqt1z1_nhch00000gn/T/ipykernel_72035/1829591939.py:1: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similar = [(token.text, wapo_proc_md.similarity(token))

# %%
# Top 10 most similar words

def Sort_Tuple(tup):
 
    tup.sort(reverse=True, key = lambda x: x[1])
    return tup

print(Sort_Tuple(similar[0:10]))
# Out:
# [('considerable', 0.802863169306438), ('surrounding', 0.7833047686043321), ('buffering', 0.7823169808875561), ('especially', 0.7789593371668303), ('dramatically', 0.7765756515225591), ('significance', 0.772368379941853), ('suggesting', 0.7580252619466579), ('potentially', 0.7558103332039718), ('potentially', 0.7558103332039718), ('Diversion', 0.7520432849106711)]

# %% [markdown]
#     The top 10 most similar words in the article are 'considerable' with a score of 0.803, 'surrounding' with 0.783, 'buffering' with 0.782, 'especially' with 0.779, 'dramatically', with 0.777, 'siginifiance' with 0.772, 'suggesting' with 0.758, 'potentially' with 0.756, 'potentially' again with the same score, and 'Diversion' with a score of 0.752.
